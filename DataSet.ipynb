# %%
import pandas as pd              
import numpy as np               
import matplotlib.pyplot as plt  

df = pd.read_csv('auto_mpg.csv')# stocker les donnees de la dataset vers tableau df(dataframe)

print(f"nbr de lignes: {df.shape[0]}")      #              afficher nbr de ligne et
print(f"nbr de colonnes: {df.shape[1]} \n") #              colonnes dans df

print(df.head() )# afficher les premieres lignes (juste pour voir la structure de df)  

print("_" * 80)

print(df.describe().round(2))#afficher les statistiques du dataset(moyenne,medianne,min,max.....)

print("_" * 80)

print("Valeurs manquantes:")#            afficher nbr de valeurs
print(df.isnull().sum())    #            manquantes dans chaque colonne
# Out:
# nbr de lignes: 392
# nbr de colonnes: 7
#
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  33.9          4         118.6       137.0    3822          20.2          73
# 1  38.2          8         239.3        92.6    2327          13.8          72
# 2  39.5          6         194.6        79.1    3238          15.7          82
# 3  38.1          6         181.0       142.0    2638          17.8          79
# 4  46.2          4         134.7        71.8    2626          10.7          81
# ________________________________________________________________________________
#           mpg  cylinders  displacement  horsepower   weight  acceleration  \
# count  392.00     392.00        392.00      392.00   392.00        392.00
# mean    39.48       5.43        165.01      104.83  2804.71         15.14
# std      4.63       1.56         49.83       37.15   762.81          2.96
# min     26.60       4.00         90.00       40.00  1500.00          8.00
# ...
